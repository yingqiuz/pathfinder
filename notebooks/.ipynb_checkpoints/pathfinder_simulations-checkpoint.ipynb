# %% [markdown]
# # Test PathFinder with simulated data
#
# Generate random data with known rank and test Pathfinder's ability to reconstruct the data.

# %%
from pathfinder import decomp, utils

# -- here while dev in progress
import importlib
importlib.reload(utils)
importlib.reload(decomp)
# ---

# simulate data
data, data_complete = utils.simulate_data_grid(num_domains=3, 
                                               num_modalities=4, 
                                               missing=[(0,1),(0,3),(1,3),(2,1),(2,2)],
                                               output_complete=True)

# visualise data organisation
_ = utils.plot_data_grid(data)

# %%
# Fit the data
from sklearn.linear_model import Ridge
algo = decomp.JointDecomp(n_components=5, n_iter=30, dropout=-1,
                          method=Ridge, method_kwargs={'alpha':1e2})

A, S, err = algo.fit(data)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 30/30 [00:01<00:00, 24.68it/s]

# %%
# Plot error

_ = utils.plot_error(err)

# %%
# Plot data and fit
_ = utils.plot_data_fit(data, A, S, data_complete)
